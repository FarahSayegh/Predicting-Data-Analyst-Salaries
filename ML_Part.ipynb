# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedShuffleSplit
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
import joblib
from xgboost import XGBRegressor

# %%
df = pd.read_csv('clean.csv')

# %%
df.head()
# Out:
#                 job_title salary_estimate  \
# 0            Data Analyst         37 - 66
# 1    Quality Data Analyst         37 - 66
# 2     Senior Data Analyst         37 - 66
# 3            Data Analyst         37 - 66
# 4  Reporting Data Analyst         37 - 66
#
#                                      job_description  rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                          company_name      location  headquarters  \
# 0           Vera Institute of Justice  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York  New York, NY  New York, NY
# 2                         Squarespace  New York, NY  New York, NY
# 3                            Celerity  New York, NY    McLean, VA
# 4                             FanDuel  New York, NY  New York, NY
#
#                      size  founded               type_of_ownership  ...  \
# 0    201 to 500 employees     1961          Nonprofit Organization  ...
# 1        10000+ employees     1893          Nonprofit Organization  ...
# 2  1001 to 5000 employees     2003               Company - Private  ...
# 3    201 to 500 employees     2002  Subsidiary or Business Segment  ...
# 4   501 to 1000 employees     2009               Company - Private  ...
#
#   Python Bachelor  Master  No_degree  job_city job_state   hq_city  hq_state  \
# 0      1        0       0          1  New York        NY  New York        NY
# 1      0        1       1          0  New York        NY  New York        NY
# 2      1        1       1          0  New York        NY  New York        NY
# 3      0        1       0          0  New York        NY    McLean        VA
# 4      1        1       0          0  New York        NY  New York        NY
#
#    age   age_bin
# 0   63       old
# 1  131  very old
# 2   21       new
# 3   22       new
# 4   15       new
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['job_title', 'salary_estimate', 'job_description', 'rating',
#        'company_name', 'location', 'headquarters', 'size', 'founded',
#        'type_of_ownership', 'sector', 'revenue', 'min_salary', 'max_salary',
#        'average_salary', 'average_salary_bin', 'SQL', 'Excel', 'Tableau', 'R',
#        'Power BI', 'SAS', 'Word', 'PowerPoint', 'AWS', 'Python', 'Bachelor',
#        'Master', 'No_degree', 'job_city', 'job_state', 'hq_city', 'hq_state',
#        'age', 'age_bin'],
#       dtype='object')

# %%
df['revenue'].unique()
# Out:
# array(['$100 to $500 million (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', '$50 to $100 million (USD)',
#        '$1 to $2 billion (USD)', '$5 to $10 billion (USD)',
#        '$1 to $5 million (USD)', '$25 to $50 million (USD)',
#        '$10+ billion (USD)', 'Less than $1 million (USD)',
#        '$10 to $25 million (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 million (USD)'], dtype=object)

# %%
columns_to_drop = ['salary_estimate','job_description','location','headquarters','founded','min_salary','max_salary']

# %%
categorical_features = ['job_title','company_name','type_of_ownership','sector','job_city','job_state','hq_city','hq_state']

# %%
df[categorical_features].head()
# Out:
#                 job_title                        company_name  \
# 0            Data Analyst           Vera Institute of Justice
# 1    Quality Data Analyst  Visiting Nurse Service of New York
# 2     Senior Data Analyst                         Squarespace
# 3            Data Analyst                            Celerity
# 4  Reporting Data Analyst                             FanDuel
#
#                 type_of_ownership                            sector  job_city  \
# 0          Nonprofit Organization                        Non-Profit  New York
# 1          Nonprofit Organization                       Health Care  New York
# 2               Company - Private            Information Technology  New York
# 3  Subsidiary or Business Segment            Information Technology  New York
# 4               Company - Private  Arts, Entertainment & Recreation  New York
#
#   job_state   hq_city hq_state
# 0        NY  New York       NY
# 1        NY  New York       NY
# 2        NY  New York       NY
# 3        NY    McLean       VA
# 4        NY  New York       NY

# %%
numeric_features = ['age']

# %%
size_encoder = OrdinalEncoder(categories=[['Unknown','1 to 50 employees','51 to 200 employees','201 to 500 employees','501 to 1000 employees','1001 to 5000 employees','5001 to 10000 employees','10000+ employees']],handle_unknown="use_encoded_value", unknown_value= -1)
revenue_encoder = OrdinalEncoder(categories=[['Unknown / Non-Applicable','Less than $1 million (USD)','$1 to $5 million (USD)','$5 to $10 million (USD)','$10 to $25 million (USD)','$25 to $50 million (USD)','$50 to $100 million (USD)','$100 to $500 million (USD)','$500 million to $1 billion (USD)',\
                                 '$1 to $2 billion (USD)','$2 to $5 billion (USD)','$5 to $10 billion (USD)','$10+ billion (USD)'
                                 ]],handle_unknown="use_encoded_value", unknown_value= -1)

#average_salary_bin_encoder = OrdinalEncoder(categories= [['low','medium','high']],handle_unknown="use_encoded_value", unknown_value= -1)
age_encoder = OrdinalEncoder(categories= [['Unknown','new','old','very old']], handle_unknown="use_encoded_value", unknown_value= -1)

# %%
#y = df['average_salary']

# %%
num_bins = 10
df['average_salary_bin'] = pd.cut(df['average_salary'], bins=num_bins, labels=False)

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df, df['average_salary_bin']):
    strat_train_set = df.iloc[train_index]
    strat_test_set = df.iloc[test_index]

# %%
strat_train_set = strat_train_set.drop(columns=['average_salary_bin'])
strat_test_set = strat_test_set.drop(columns=['average_salary_bin'])

# %%
X_train = strat_train_set.drop(columns=['average_salary'])
y_train = strat_train_set['average_salary']
X_test = strat_test_set.drop(columns=['average_salary'])
y_test = strat_test_set['average_salary']

# %%
#X = df.drop(['average_salary','average_salary_bin'],axis = 1)

# %%
#X.drop(columns_to_drop, axis = 1, inplace = True)

# %%
X_train.drop(columns_to_drop, axis = 1, inplace = True)
X_test.drop(columns_to_drop, axis = 1, inplace = True)

# %%
#x_train, x_, y_train, y_ = train_test_split(X, y, test_size = 0.4, random_state = 42)
#x_val, x_test, y_val, y_test = train_test_split(x_,y_, test_size = 0.5, random_state = 42)
#del x_,y_

# %%
ct = ColumnTransformer(
    [
    ('standard_scaler', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
    ('size_encoder', size_encoder, ['size']),
    ('revenue_encoder', revenue_encoder, ['revenue']),
    ('age_encoder', age_encoder, ['age_bin']),
    ], remainder='passthrough'
)

# %%
n = OneHotEncoder(handle_unknown='ignore').fit_transform(X_train[categorical_features]).toarray()

# %%
#n

# %%
X_train.columns
# Out:
# Index(['job_title', 'rating', 'company_name', 'size', 'type_of_ownership',
#        'sector', 'revenue', 'SQL', 'Excel', 'Tableau', 'R', 'Power BI', 'SAS',
#        'Word', 'PowerPoint', 'AWS', 'Python', 'Bachelor', 'Master',
#        'No_degree', 'job_city', 'job_state', 'hq_city', 'hq_state', 'age',
#        'age_bin'],
#       dtype='object')

# %%
ct.fit_transform(X_train)
# Out:
# <1800x2754 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28696 stored elements in Compressed Sparse Row format>

# %%
feature_selection_model = RandomForestRegressor(n_jobs = -1, n_estimators= 100, random_state=42)
pipeline = Pipeline([
    ('preprocessing', ct),
    ('feature_selection', SelectFromModel(estimator=feature_selection_model, threshold='median')),
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standard_scaler',
#                                                   StandardScaler(), ['age']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['job_title', 'company_name',
#                                                    'type_of_ownership',
#                                                    'sector', 'job_city',
#                                                    'job_state', 'hq_city',
#                                                    'hq_state']),
#                                                  ('size_encoder',
#                                                   OrdinalEncoder(categories=[['Unknown',
#                                                                               '1 '
#                                                                               'to '
#                                                                               '50 '
#                                                                               'e...
#                                                                               'billion '
#                                                                               '(USD)']],
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['revenue']),
#                                                  ('age_encoder',
#                                                   OrdinalEncoder(categories=[['Unknown',
#                                                                               'new',
#                                                                               'old',
#                                                                               'very '
#                                                                               'old']],
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['age_bin'])])),
#                 ('feature_selection',
#                  SelectFromModel(estimator=RandomForestRegressor(n_jobs=-1,
#                                                                  random_state=42),
#                                  threshold='median'))])

# %%
feature_selection_step = pipeline.named_steps['feature_selection']
selected_feature_indices = feature_selection_step.get_support(indices=True)
len(selected_feature_indices)
#selected_feature_names = x_train.columns[selected_feature_indices].tolist()
# Out:
# 1377

# %%
pipeline.fit(X_train, y_train)
print("Shape of x_train:", X_train.shape)
print("Feature selection step:", pipeline.named_steps['feature_selection'])
# Out:
# Shape of x_train: (1800, 26)
# Feature selection step: SelectFromModel(estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#                 threshold='median')

# %%
feature_selection_step = pipeline.named_steps['feature_selection']
selected_feature_indices = feature_selection_step.get_support(indices=True)

# %%
numeric_features_names = ct.transformers_[0][2] 
categorical_features_names = ct.transformers_[1][1].get_feature_names_out(categorical_features) 
ordinals_features = ['size', 'revenue', 'age']
remaining_features = ct.transformers_[5][1].get_feature_names_out()

# %%
selected_feature_names = []
selected_feature_names.extend(numeric_features_names)
selected_feature_names.extend(categorical_features_names)
selected_feature_names.extend(ordinals_features)
selected_feature_names.extend(remaining_features)

# %%
len(selected_feature_names)
# Out:
# 2754

# %%
print(selected_feature_indices)
# Out:
# [   0    1    2 ... 2751 2752 2753]

# %%
for idx in selected_feature_indices:
    print(selected_feature_names[idx])
# Out:
# age
# job_title_ Summer Analyst Program
# job_title_# Division Data And Financial Analyst
# job_title_.Net
# job_title_.Net Developer
# job_title_Acoustics Data Analyst/Flight Test Engineer
# job_title_Ai Insights Data Analyst
# job_title_Analyst Data Intelligence (Us)
# job_title_Apple Media Products (Amp)
# job_title_Application Data Analyst
# job_title_Application Programmer V/ Database Developer/ Data Analyst
# job_title_Associate Player Support Data Analyst
# job_title_Associate Salesforce.Com Data Steward & Analyst
# job_title_Automotive Data Analyst
# job_title_Aws Analys/ Data Analyst
# job_title_Bi Developer
# job_title_Bi/Data Analyst
# job_title_Big Data Analyst
# job_title_Bilingual (Chinese) Data Analyst
# job_title_Biological Data Analyst
# job_title_Biomedical Data Analyst I
# job_title_Business Analyst
# job_title_Cbo Data Analyst
# job_title_Ccpa Data Analyst
# job_title_Certified Tumor Registrar/Data Analyst [Ctr And Experience Required]
# job_title_Ci Data Analyst/Engineer
# job_title_Client Data Analyst
# job_title_Clinical Data Analyst
# job_title_Clinical Practice Data Analyst Specialist (Clinical Research Data Manager)
# job_title_Compensation & Hr Data Analyst
# job_title_Compensation And Data Analyst (Human Resources)
# job_title_Configuration And Data Management (C&Dm) Analyst
# job_title_Configuration Data Analyst
# job_title_Consumer Lending Data Analyst
# job_title_Content Analyst/Data Ba
# job_title_Contract Data Analyst
# job_title_Cost Data Analyst
# job_title_Crm Data Performance Analyst
# job_title_Csv Data Validation Analyst
# job_title_Cybersecurity Analyst (Payment Card Industry Data Security Standards (Pci
# job_title_Dallas Campus Recruiting
# job_title_Data & Reporting Analyst
# job_title_Data Analyst
# job_title_Data Analyst & Healthcare Analytics
# job_title_Data Analyst ( Sas
# job_title_Data Analyst (College & Foundation Reporting)
# job_title_Data Analyst (Finance)
# job_title_Data Analyst (Hr)
# job_title_Data Analyst (Mpi)
# job_title_Data Analyst (Philadelphia
# job_title_Data Analyst (Product Analytics)
# job_title_Data Analyst (Sql
# job_title_Data Analyst (Supply Chain)
# job_title_Data Analyst / Data Management /Etl / Talend /Alteryx
# job_title_Data Analyst Bhjob_
# job_title_Data Analyst Entry Level
# job_title_Data Analyst Hedis Star
# job_title_Data Analyst I (German)
# job_title_Data Analyst Ii(Claims
# job_title_Data Analyst Iii (Population Health
# job_title_Data Analyst Intern
# job_title_Data Analyst Lead
# job_title_Data Analyst Manager
# job_title_Data Analyst Supporting The Fbi #
# job_title_Data Analyst Team — Data Analyst
# job_title_Data Analyst With Data Lineage/Rochade
# job_title_Data Analyst With Python
# job_title_Data Analyst With Python Or Python Developer
# job_title_Data Analyst With Rochade
# job_title_Data Analyst Â Junior
# job_title_Data Analyst/Architect
# job_title_Data Analyst/Data Acquisition Speciliest With Financial Industry Exp
# job_title_Data Analyst/Engineers
# job_title_Data Analyst/Program Manager
# job_title_Data Analyst/Project Manager
# job_title_Data Analyst/Project Manager In Jersey City
# job_title_Data Analytics Insights Analyst
# job_title_Data Analytics Senior Analyst
# job_title_Data Analytics Solutions Analyst
# job_title_Data And Information Analyst
# job_title_Data And Policy Analyst
# job_title_Data And Policy Analyst Iv
# job_title_Data And Reporting Analyst
# job_title_Data And User Acceptance Test Analyst
# job_title_Data Base Programmer/Analyst
# job_title_Data Center Migration Pmo Analyst/Pmo Lead
# job_title_Data Collection Analyst
# job_title_Data Conversion Analyst
# job_title_Data Engineer/Data Analyst
# job_title_Data Engineer/Reporting Analyst
# job_title_Data Engineering/Analyst
# job_title_Data Entry Analyst
# job_title_Data Entry And Compliance Analyst
# job_title_Data Entry Clerk / Data Analyst
# job_title_Data Entry Clerk And Analyst
# job_title_Data Expert Analyst/Modeler
# job_title_Data Governance Analyst
# job_title_Data Governance Analyst/Lead
# job_title_Data Governance And Analytics Analyst
# job_title_Data Integrity Analyst
# job_title_Data Intelligence Analyst
# job_title_Data Management
# job_title_Data Management Analyst
# job_title_Data Management Analyst (Addm) Sec Svcs Ops Data Governance
# job_title_Data Mgmt Analyst W/Traded Products
# job_title_Data Migration Analyst
# job_title_Data Modeler/Data Analyst
# job_title_Data Operations Analyst
# job_title_Data Platform System Analyst Lead (Data Services)
# job_title_Data Privacy Analyst/ Program Manager I
# job_title_Data Quality Analyst
# job_title_Data Quality Management Analyst
# job_title_Data Reporting Analyst
# job_title_Data Science Analyst Ii
# job_title_Data Science Lead Analyst
# job_title_Data Science Sr. Analyst
# job_title_Data Scientist
# job_title_Data Scientist/Analyst
# job_title_Data Security Analyst
# job_title_Data Security Analyst Fr
# job_title_Data Security Analytics Analyst
# job_title_Data Services Lead Analyst
# job_title_Data Standards Analyst
# job_title_Data Standards Analyst In Seattle
# job_title_Data Statistics Analyst Pfk Care Coordination
# job_title_Data Stewardship Senior Analyst
# job_title_Data Strategy Analyst
# job_title_Data Studio Analyst
# job_title_Data Systems Analyst
# job_title_Data Technician/Analyst/Specialist
# job_title_Data Warehouse Analyst
# job_title_Data Warehouse Analyst Iii
# job_title_Data Warehouse Analyst Pl/Sql
# job_title_Data Warehouse Programmer/Analyst
# job_title_Data Warehouse Systems Analyst
# job_title_Data/Report Analyst
# job_title_Data/Reporting Analyst
# job_title_Datastage Developer/Consultant/Ibm Websphere Datastage Developer(Etl Data Analyst)
# job_title_Dba / Data Analyst
# job_title_Digital Marketing Data Analyst
# job_title_Digital Media Data Analyst
# job_title_Discovery Data Analyst
# job_title_Ediscovery Data Analyst
# job_title_Electronic Data Interchange Analyst (Edi)
# job_title_Encounter Data Analyst
# job_title_Enterprise Data Analyst
# job_title_Entry Level / Jr. Data Analyst
# job_title_Epic Clarity Data Analyst
# job_title_Epic Data Intelligence Analyst
# job_title_Epidemiology Data Analyst
# job_title_Equity Data/Research Analyst
# job_title_Erp Data Migration Analyst In Glenview
# job_title_Etl Datastage Developer/Ibm Infosphere Datastage Consultant(Etl Data Analyst)
# job_title_Etl Developer / Data Analyst
# job_title_Finance Data Analyst
# job_title_Financial Controller / Data Analyst / Spreadsheet Superstar
# job_title_Financial Data Analyst
# job_title_Financial Systems Lead Data And Reporting Analyst
# job_title_Firmwide Reference Data Operations
# job_title_Food Data Analyst
# job_title_Fund Data Analyst
# job_title_Hcc Data Analyst
# job_title_Healthcare Analyst
# job_title_Healthcare Data Analyst
# job_title_Healthcare Data Analytics Analyst
# job_title_Healthcare Data Analytics Analyst Senior
# job_title_Healthcare Data/Reporting Analyst
# job_title_Healthcare Senior Data Analyst
# job_title_Hr Data Analyst
# job_title_Hr Data Analyst (Workday Eib)
# job_title_Human Capital Data Analyst
# job_title_Industry Analyst
# job_title_Informatica Idq
# job_title_Information Security Analyst
# job_title_Information Security And Data Protection Analyst
# job_title_Investment Advisory Data Analyst
# job_title_It Data Analyst
# job_title_It Data Science Analyst
# job_title_It Risk And Compliance Data Reporting Analyst
# job_title_Item Data Maintenance Analyst
# job_title_Job Opportunity With Cognizant For Data Analyst At Sfo
# job_title_Jpsc
# job_title_Junior Data Analyst
# job_title_Junior Data Analytics Solutions Analyst
# job_title_Lawson Landmark Data Extract Analyst
# job_title_Lead Analyst
# job_title_Lead Data Analyst
# job_title_Lead Data Analyst (Product)
# job_title_Lead Quality Data Analyst
# job_title_Leading Data
# job_title_Lims Master Data Analyst
# job_title_Loan Data Analyst
# job_title_Logistics Data Analyst
# job_title_Logistics Data Analyst Ii
# job_title_Manager : Marketing Ops And Data Analyst
# job_title_Maps Evaluation Data Analyst
# job_title_Market Data Analyst
# job_title_Market Data Services Analyst
# job_title_Marketing Data Analyst
# job_title_Marketing/Communications
# job_title_Master Data Analyst
# job_title_Master Data Analyst – Sap Mdg Platform
# job_title_Master Data Management (Mdm)
# job_title_Master Data Management Analyst
# job_title_Mdm Data Analyst
# job_title_Mdm/Master Data Analyst ( Tibco Ebx )
# job_title_Media Data Analyst
# job_title_Metrics & Data Analyst
# job_title_Mid
# job_title_Music Copyright Data Analyst
# job_title_Niwc Service Desk Analyst Component Enterprise Data Center (Cedc With Security Clearance
# job_title_Ny Healthcare Data/Reporting Analyst
# job_title_Operations Analyst
# job_title_Operations Data Analyst
# job_title_Payment Integrity Data Analyst
# job_title_Payment Integrity Data Analyst Job Posting In #Philadelphia #Itjobs
# job_title_People Operations & Data Analyst
# job_title_Pharmaceutical Customer Data Analyst
# job_title_Position For Lead Data Analyst (Teradata
# job_title_Practice Analyst Data
# job_title_Pricing Data Analyst
# job_title_Principal Data Analyst
# job_title_Principal Data Management Analyst
# job_title_Principal Sales Operations Analyst
# job_title_Procurement Data Analyst
# job_title_Product And Data Analyst
# job_title_Product Compliance Data Analyst
# job_title_Product Data Analyst
# job_title_Program Analyst
# job_title_Programmer Data Analyst
# job_title_Project Regulatory/Risk Data Analyst
# job_title_Qa Analyst
# job_title_Qa Analyst With Mongodb / Big Data
# job_title_Qa Data Analyst
# job_title_Qa Production Data Analyst
# job_title_Qm Data Analyst Ii
# job_title_Quality Data Analyst
# job_title_Radar Telemetry Data Analyst
# job_title_Remote Data Analyst
# job_title_Reporting Data Analyst
# job_title_Research Data Analyst
# job_title_Risk Data Analyst
# job_title_Rqs
# job_title_Sales Data Analyst
# job_title_Sales Finance Data Analyst
# job_title_Sap Data Analyst
# job_title_Sap Data Management Analyst
# job_title_Sap Master Data Analyst
# job_title_Sas Data Analyst
# job_title_Sas Data Analyst/Reports Writer
# job_title_Scientific Data Manager And Analyst
# job_title_Senior Bi And Data Analyst
# job_title_Senior Clinical Data Analyst
# job_title_Senior Cloud Data Analyst
# job_title_Senior Contract Data Analyst
# job_title_Senior Customer Data Analyst :
# job_title_Senior Cx Data Analyst
# job_title_Senior Data Analyst
# job_title_Senior Data Analyst (Corporate Audit)
# job_title_Senior Data Analyst (Product)
# job_title_Senior Data Analyst / Scientist
# job_title_Senior Data Analyst Informatics
# job_title_Senior Data Analyst Studio Finance Engineering
# job_title_Senior Data Analytics Solutions Analyst
# job_title_Senior Data Analytics Solutions Analyst With Security Clearance
# job_title_Senior Data And Fraud Analyst
# job_title_Senior Data Bi Analyst
# job_title_Senior Data Engineer & Analyst
# job_title_Senior Data Insights Analyst
# job_title_Senior Data Management Analyst
# job_title_Senior Data Management Analyst (Sdma)
# job_title_Senior Data Operations Analyst
# job_title_Senior Data Quality Analyst
# job_title_Senior Data Strategy Analyst (Sdsa)
# job_title_Senior Financial Data Analyst
# job_title_Senior Functional Analyst Sap Data Design
# job_title_Senior Health Data Analyst
# job_title_Senior Healthcare Data Analyst
# job_title_Senior Hr Data Analyst
# job_title_Senior It Technical Data Analyst
# job_title_Senior Market Data Content Acquisition/Procurement Analyst
# job_title_Senior Market Research Analyst
# job_title_Senior Marketing Data Analyst
# job_title_Senior Product Data Analyst
# job_title_Senior Quantitative Data Analyst
# job_title_Senior Research Data Analyst
# job_title_Senior Risk Analyst
# job_title_Senior Solutions Analyst
# job_title_Senior Specialist Data Analyst
# job_title_Senior Sql Data Warehouse Analyst
# job_title_Senior Strategy Data Analyst
# job_title_Senior Technical Data Analyst
# job_title_Service Operations Data Analyst
# job_title_Simulation Data Analyst
# job_title_Software Engineer/Data Analyst
# job_title_Solar Data Analyst
# job_title_Specialist
# job_title_Splunk Data Analyst
# job_title_Sql Data Analyst
# job_title_Sql Report Developer Data Analyst
# job_title_Sr Data Analyst (Dw)
# job_title_Sr Data Analyst For Customer Based Management
# job_title_Sr Data Analyst/Data Warehouse Consultant With Financial Healthcare Systems
# job_title_Sr It Technical Data Analyst
# job_title_Sr Performance Metrics Data Analyst
# job_title_Sr Python Data Analyst(No Cc) Contract W Only
# job_title_Sr. Bi Data Analyst / Qliksense
# job_title_Sr. Bi Data Analyst/Developer (Sql
# job_title_Sr. Ci Data Analyst/Engineer
# job_title_Sr. Data Analyst (Pharmacy)
# job_title_Sr. Data Analyst — Us Safety
# job_title_Sr. Data Governance Analyst
# job_title_Sr. Data Scientist/Analyst
# job_title_Sr. Data/Report System Analyst
# job_title_Sr. Datastage And Data Analyst
# job_title_Sr. Principal Metrics Analyst
# job_title_Stability Data Analyst
# job_title_Strategic Data Analyst Iii
# job_title_Supply Chain Data Analyst
# job_title_Sustainability Data Analyst
# job_title_System And Data Analyst
# job_title_System/Data Analyst
# job_title_Systems Analyst
# job_title_Tableau Data Analyst Intern
# job_title_Tactical Data Link (Tdl) Analyst
# job_title_Technical Analyst
# job_title_Technical Data Analyst
# job_title_Technical Data Analyst Accounting
# job_title_Technical Web Data Collection Analyst
# job_title_Technology Control Analyst
# job_title_Tx Healthcare Data/Reporting Analyst
# job_title_Vba Software Developer / It Data Analyst Sql
# job_title_Vertical Lift Data Exploitation Analyst
# job_title_Visiting Undergraduate Affairs Data Analyst
# job_title_Vp
# job_title_Web Data Analyst
# job_title_Woocommerce Data Governance Analyst
# job_title_Workday Eib Data Analyst
# job_title_Xyz Data Analyst
# job_title_nan
# company_name_1872 Consulting
# company_name_22nd Century Technologies
# company_name_911 Datamaster Inc
# company_name_A2C Consulting
# company_name_ACT Consulting
# company_name_AKORBI Language Solutions
# company_name_APN Consulting
# company_name_APN Software Services Inc.
# company_name_ARK Solutions, Inc.
# company_name_Abacus Service Corporation
# company_name_AbleTo
# company_name_AccessLex Institute
# company_name_Activision Blizzard
# company_name_Acumen
# company_name_Addison Group
# company_name_Advent Global Solutions - Special Instance
# company_name_Advisor Group
# company_name_Adwait Algorithm
# company_name_Aegis Media
# company_name_Ajilon
# company_name_Akraya Inc.
# company_name_Albany Charter School Network
# company_name_AllRedi
# company_name_Alteryx
# company_name_Altice USA
# company_name_Amazon Corporate LLC
# company_name_American CyberSystems
# company_name_Amerihealth Caritas Health Plan
# company_name_Amyx, Iinc.
# company_name_Apex Systems
# company_name_Apollo Global Management
# company_name_Apollo Medical Holdings, Inc.
# company_name_Apple
# company_name_AppleOne
# company_name_Applicantz, Inc.
# company_name_Apto Payments
# company_name_Artech LLC
# company_name_Arthur Lawrence
# company_name_Ascension
# company_name_Ascent
# company_name_Aspen Careers, LLC
# company_name_Atos
# company_name_Atos Healthcare
# company_name_Atrium Staffing
# company_name_Attentive
# company_name_Autodesk
# company_name_Avacend, Inc.
# company_name_Avani Technology Solutions
# company_name_Avetta, LLC
# company_name_Aviana Global Technologies, Inc
# company_name_BMO
# company_name_BNY Mellon
# company_name_BOLD
# company_name_Bandai Namco Entertainment America
# company_name_Barnabas Health
# company_name_BayOne Solutions
# company_name_Bazaarvoice
# company_name_Beezwax Datatools
# company_name_Bloom Ads Global Media Group
# company_name_Blue Rock Consulting
# company_name_Blue Shield of California
# company_name_Bounce Exchange
# company_name_Brink's
# company_name_BulbHead
# company_name_BurnsSearch, LLC
# company_name_C&G Consulting Services
# company_name_CMI/Compas
# company_name_Calsoft Labs
# company_name_Cambridge Advisory Group
# company_name_Capgemini
# company_name_Capgemini America, Inc.
# company_name_Capital Management
# company_name_Catasys Health
# company_name_Cecelia Health
# company_name_Cedent Consulting
# company_name_Cenergy
# company_name_Cenergy International
# company_name_Central Business Solutions, Inc
# company_name_Central Health
# company_name_CenturyLink
# company_name_Chenega Healthcare Services
# company_name_Chime
# company_name_Chime Bank
# company_name_Chinese Community Health Plan
# company_name_Circle Logistics
# company_name_Citi
# company_name_City National Bank
# company_name_City and County of San Francisco
# company_name_Clear Technology Consulting
# company_name_CloudFlare
# company_name_CodeGreen Solutions
# company_name_Cognoa
# company_name_Coinbase
# company_name_Collabera
# company_name_Columbia University Medical Center
# company_name_Community Behavioral Health
# company_name_CompuForce
# company_name_Computer Enterprises, Inc.
# company_name_Concept Software & Services Inc
# company_name_ConcertAI
# company_name_Conch Technologies, Inc
# company_name_Connor Group
# company_name_ConsultNet, LLC
# company_name_Contemporary Staffing Solutions
# company_name_Contingent Network Services
# company_name_Cooper University Health Care
# company_name_Crawford Thomas Recruiting
# company_name_Creative Circle
# company_name_Creative Financial Staffing
# company_name_Credible
# company_name_Crown Castle USA Inc
# company_name_Crystal Equation
# company_name_Cyber Warrior Network
# company_name_CyberCoders
# company_name_Cyclex Systems
# company_name_Cypress HCM
# company_name_DL Staffing Solutions
# company_name_DT Professional Services
# company_name_Dash Technologies Inc
# company_name_Dave
# company_name_Deacon Recruiting
# company_name_Delaware Investments Colorado Municipal Income Fund, Inc
# company_name_Delmarva Foundation
# company_name_Delphi-US
# company_name_Devotion Business Solutions
# company_name_Disney Streaming Services
# company_name_Diversant LLC
# company_name_Diverse Lynx
# company_name_Dollar Shave Club
# company_name_Dot818
# company_name_Doximity
# company_name_Duetto
# company_name_EAG Services
# company_name_ERGO
# company_name_EVERSANA
# company_name_EY
# company_name_Eagle Investment Systems
# company_name_Earnest Research
# company_name_Education Development Center, Inc.
# company_name_Endai
# company_name_Endpoint Closing
# company_name_Episcopal Health Services Inc.
# company_name_Ernst & Young LLP
# company_name_Eurofins
# company_name_Evolver, Inc.
# company_name_Exact Sciences Corporation
# company_name_Facebook
# company_name_Fair Health
# company_name_FanDuel
# company_name_First Republic Bank
# company_name_Flatiron Health
# company_name_Fleishman-Hillard Inc
# company_name_Flexport
# company_name_ForeFlight
# company_name_Forfeiture Support Associates
# company_name_Fox Chase Cancer Center
# company_name_Franklin Resources
# company_name_Freedom Financial Network
# company_name_Freedom Mortgage
# company_name_GasPedal
# company_name_Gemalto
# company_name_Genesys Talent
# company_name_Genpact
# company_name_Georgia IT Inc.
# company_name_Giving Assistant
# company_name_GoAhead Solutions
# company_name_Gopuff
# company_name_Green Key Resources
# company_name_Guidehouse
# company_name_HR Pundits
# company_name_Harris Computer
# company_name_Harris County Appraisal District
# company_name_Harris Health System
# company_name_HealthHelp
# company_name_Healthfirst
# company_name_Hearst Communications
# company_name_Hexacorp
# company_name_Hilltop Holdings
# company_name_Hinge Health
# company_name_HireTalent
# company_name_Horizon Blue Cross Blue Shield of New Jersey
# company_name_Hotel Compete
# company_name_Houston Exponential
# company_name_Human Coalition
# company_name_Hyliion
# company_name_IBM
# company_name_ICAP at Columbia University
# company_name_ICONMA
# company_name_ICONMA, LLC
# company_name_IPRO
# company_name_IPro.org
# company_name_IT Avalon
# company_name_ITech Recruiting
# company_name_Icahn School of Medicine at Mount Sinai
# company_name_Icon Consultants
# company_name_Iconma, L.L.C.
# company_name_IlliniCare Health Plan
# company_name_Impaq International, Llc
# company_name_Imperastaff, LLC
# company_name_Incedo Inc
# company_name_Infinity Consulting Solutions
# company_name_Infonex Technologies, Inc.
# company_name_Informa
# company_name_Informa Intelligence
# company_name_Information Technology Partners
# company_name_Infotree Service Inc
# company_name_Insight Enterprises, Inc.
# company_name_Integra Managed Care
# company_name_IntelliPro Group Inc.
# company_name_Intelliswift Software Inc
# company_name_Intercontinental Exchange, Inc.
# company_name_Internet Brands, Inc.
# company_name_Iris Plans Inc.
# company_name_J.P. Morgan
# company_name_JPMorgan Chase
# company_name_JPMorgan Chase Bank, N.A.
# company_name_Jam City
# company_name_Jay Hill Repairs
# company_name_Jobot
# company_name_Jon French / TechTalent Services
# company_name_Joomag, Inc.
# company_name_KLM Careers
# company_name_Kbyte Systems LLC.
# company_name_Kelly
# company_name_Kelly IT
# company_name_Kelsey Seybold Clinic
# company_name_Kelsey-Seybold Medical Group
# company_name_Kforce
# company_name_Kforce Technology Staffing
# company_name_Kharon
# company_name_Kinship
# company_name_KnowledgePro, LLC
# company_name_Koger LLC
# company_name_L&T Infotech
# company_name_L.A. Care Health Plan
# company_name_Lark Health
# company_name_LeadStack
# company_name_LeadStack, Inc.
# company_name_Lean Data
# company_name_Leap
# company_name_LendingTree, LLC.
# company_name_Leo Tech, LLC
# company_name_Lidl
# company_name_Life360
# company_name_LiveCareer
# company_name_LiveGlam
# company_name_LiveMindz
# company_name_Lodestone
# company_name_Login Consulting Services
# company_name_Login Consulting Services, Inc
# company_name_Lorven Technologies Inc
# company_name_Lucky Day
# company_name_Luminess Cosmetics
# company_name_Lyft
# company_name_M&T Bank Corporation
# company_name_MT Global US INC
# company_name_Macquarie Group
# company_name_Maine Pointe
# company_name_Maisonette Careers
# company_name_Match Group
# company_name_McAfee
# company_name_McGrath Systems
# company_name_McLane Global
# company_name_Medical Home Network
# company_name_Medline Industries
# company_name_Mercury Insurance Group
# company_name_Metroplus Health Plan
# company_name_Metropolitan Council on Jewish Poverty
# company_name_Metropolitan Family Services
# company_name_Micro-Data Systems Inc.
# company_name_Micro-Data Systems, Inc.
# company_name_Mike's Hard Lemonade
# company_name_Mindteck
# company_name_Mitchell Martin
# company_name_Mobilityware
# company_name_Molina Healthcare
# company_name_Momentum Solar
# company_name_Mondo
# company_name_Monkey Algorithms LLC
# company_name_Montefiore Medical
# company_name_Motiv Power Systems
# company_name_Motorola Solutions
# company_name_Mount Sinai Health System
# company_name_Mount Sinai Medical Center
# company_name_Moveworks
# company_name_Museum of Ice Cream
# company_name_MyLife.com
# company_name_NADAP
# company_name_NJF Global Holdings
# company_name_NRC INC
# company_name_NTT DATA, Inc.
# company_name_NVIDIA
# company_name_National Computing Group
# company_name_Nationwide Childrens Hospital
# company_name_Nesco Resource, LLC
# company_name_Net2Source
# company_name_NetSource, Inc.
# company_name_Netflix
# company_name_Netflix, Inc.
# company_name_Neustar
# company_name_New York Times
# company_name_Newspaper Administration
# company_name_NextDeavor Services
# company_name_Northrop Grumman
# company_name_Northwell Health
# company_name_Numeric, LLC
# company_name_Nuro
# company_name_OKCoin
# company_name_OSI Engineering
# company_name_Oakwood Search - CHURN
# company_name_Oasis Systems
# company_name_Octo Consulting Group
# company_name_Onyx CenterSource
# company_name_Operation Samahan Health Clinic
# company_name_Oracle
# company_name_Orbis, Inc.
# company_name_PEAK6 Investments
# company_name_PETADATA
# company_name_PIH Health
# company_name_PMHCC, Inc.
# company_name_PRIMUS Global Services, Inc
# company_name_PRO Unlimited @ Facebook
# company_name_Pacific Clinics
# company_name_Pareto Systems
# company_name_Parker Institute for Cancer Immunotherapy
# company_name_Parsoft LLC
# company_name_PeerStreet
# company_name_Perficient
# company_name_Perspecta
# company_name_Peyton Resource Group
# company_name_Pieces Technology, Inc.
# company_name_Pinnacle Technical Resources, Inc.
# company_name_Piper Companies
# company_name_PlayQ
# company_name_PlushCare
# company_name_Potomac Management
# company_name_Praescient Analytics
# company_name_Precision
# company_name_Priceonomics
# company_name_Primesoft
# company_name_ProMedia
# company_name_Professional Enrollment Concepts
# company_name_Professional Resource Group
# company_name_Providence Health & Services
# company_name_Q2eBanking
# company_name_QUICKEN INVESTMENT SERVICES, INC.
# company_name_Quantilus, Inc
# company_name_Quest Diagnostics
# company_name_QuinStreet
# company_name_Quinn Company CAT
# company_name_Quinn Group
# company_name_Quinn Group, Inc.
# company_name_RAMPS International Inc
# company_name_RGP
# company_name_RMS Computer
# company_name_RMS Computer Corporation
# company_name_RN Staff
# company_name_RWJBarnabas Health
# company_name_Radiant Digital
# company_name_Radiology Partners
# company_name_Rainier Valley Leadership Academy
# company_name_Randstad
# company_name_Recruiting Resources, Inc.
# company_name_Redfin
# company_name_Redolent, Inc
# company_name_Relevante, Inc.
# company_name_Reliable Software Resources
# company_name_Remitly
# company_name_Risk Management Solutions (RMS)
# company_name_Riskified
# company_name_Riskonnect
# company_name_Roar Digital
# company_name_Robert Half
# company_name_Robinhood
# company_name_Rockstar Games
# company_name_Rose International
# company_name_Rosen
# company_name_Royal Communications Consultants Inc
# company_name_Russell Tobin & Associates
# company_name_SACC
# company_name_SAG-AFTRA Health Plan and SAG-Producers Pension Plan
# company_name_SAP
# company_name_SAT Healthcare
# company_name_SCAN Health Plan
# company_name_SCL Health
# company_name_SF IHSS Public Authority
# company_name_SGA Inc.
# company_name_SMBC
# company_name_SMBC Group
# company_name_SMIT Solutions
# company_name_SNIPEBRIDGE
# company_name_SOFTHQ INC
# company_name_Saama Technologies Inc
# company_name_Sahara Management Inc.
# company_name_Saicon Consultants Inc
# company_name_Santanna Energy Services
# company_name_Scale AI
# company_name_Scale AI, Inc.
# company_name_Selby Jennings Buyside
# company_name_Serverlogic
# company_name_Servient
# company_name_Seven Seven Softwares
# company_name_Sharpedge Solutions Inc
# company_name_Shorenstein Realty Services L.P.
# company_name_Show Me Leads
# company_name_SigmaWay
# company_name_Signode
# company_name_Siri InfoSolutions
# company_name_Skiltrek
# company_name_Sky I.T. Group (Sky Business Intelligence Team)
# company_name_Smartwebs, Inc.
# company_name_Smith Hanley Associates
# company_name_Snowflake Computing
# company_name_Softcom Systems
# company_name_Softinc
# company_name_Softova Inc
# company_name_Softpath System LLC
# company_name_Software Guidance & Assistance
# company_name_SoluStaff
# company_name_Sonic Healthcare USA
# company_name_Source Alliance Network LLC
# company_name_Spectrum Comm
# company_name_Sphinix Network Solutions Inc.
# company_name_Sphinix Solutions
# company_name_Spiceorb
# company_name_Spin
# company_name_Square
# company_name_Square One Resources
# company_name_Square Trade
# company_name_Squarespace
# company_name_Staffigo Technical Services, LLC
# company_name_Stanford School of Medicine
# company_name_Stark HR Consulting LLC
# company_name_Steiner Electric Co
# company_name_Strategic Staffing Solutions
# company_name_Sumitomo Mitsui Banking Corporation (SMBC)
# company_name_Superior HealthPlan
# company_name_SureCritic
# company_name_Sycuan Casino
# company_name_Synchronous Solutions, Inc
# company_name_TCOE
# company_name_TD Bank
# company_name_TSR Consulting
# company_name_TSR, Inc.
# company_name_Tachyon Technologies LLC
# company_name_Take-Two
# company_name_Talent Bundle LLC
# company_name_TalentBurst, Inc.
# company_name_TalentDash
# company_name_Teachers Pay Teachers
# company_name_TeamSoft
# company_name_TechProjects
# company_name_TechUSA
# company_name_Tecolote Research
# company_name_Tekfortune Inc.
# company_name_Telnet (Rockville, MD)
# company_name_Tempus
# company_name_Tempus Labs
# company_name_Tetra Tech
# company_name_Texas Dow Employees Credit Union
# company_name_Texas Facilities Commission
# company_name_Texas Health & Human Services Commission
# company_name_Texas Water Development Board
# company_name_The Bank of New York Mellon
# company_name_The Denzel Group
# company_name_The Judge Group
# company_name_The Judge Group, Inc.
# company_name_The Jupiter Group
# company_name_The Rock Church
# company_name_The Voleon Group
# company_name_Thermo Fisher Scientific
# company_name_TikTok
# company_name_Tilde Staff Inc.
# company_name_Tillster
# company_name_Top Prospect Group, Inc.
# company_name_TopTalentFetch
# company_name_Trifacta
# company_name_Trilogy Behavioral Health
# company_name_Tripalink
# company_name_Turn/River Capital
# company_name_Turner Broadcasting
# company_name_Two Sigma
# company_name_Two95 International Inc.
# company_name_TxDOT
# company_name_U.S. Auto Parts Network, Inc.
# company_name_UBS
# company_name_UC San Diego
# company_name_UCSF Medical Center
# company_name_USDM Life Sciences
# company_name_UTHealth Houston
# company_name_Undertone
# company_name_United IT Solutions
# company_name_University of Illinois Medical Center
# company_name_Ursus
# company_name_User Testing
# company_name_V R Della Infotech Inc
# company_name_V3 Talent Partners Inc.
# company_name_VITALWARE LLC
# company_name_VTS
# company_name_Vaco
# company_name_Vanguard
# company_name_Vastika
# company_name_Veem
# company_name_Vera Institute of Justice
# company_name_Verb Surgical
# company_name_Vervent
# company_name_Vestracare
# company_name_Village Care
# company_name_Vinsari LLC
# company_name_Virtus Partners LLC
# company_name_Visiting Nurse Service of New York
# company_name_Vsion Technologies Inc
# company_name_WB Technology
# company_name_Walgreens
# company_name_Warner Bros. Entertainment
# company_name_Washington Federal
# company_name_Western Asset
# company_name_Weston Solutions Inc.
# company_name_Wider Circle
# company_name_Wilbur Labs
# company_name_Wittij Consulting
# company_name_Workforce Logiq
# company_name_Xcutives.com Inc
# company_name_Xoriant Corporation
# company_name_ZS Associates
# company_name_Zachary Piper Solutions, LLC
# company_name_Zipongo
# company_name_addastaff
# company_name_amerihealth
# company_name_eHealth
# company_name_eTeam Inc.
# company_name_enexusglobal
# company_name_iSpace, Inc
# company_name_nWay
# company_name_softsnippets
# company_name_zz-Tarzana Treatment Centers, Inc.
# type_of_ownership_College / University
# type_of_ownership_Company - Private
# type_of_ownership_Company - Public
# type_of_ownership_Contract
# type_of_ownership_Franchise
# type_of_ownership_Government
# type_of_ownership_Hospital
# type_of_ownership_Nonprofit Organization
# type_of_ownership_Other Organization
# type_of_ownership_Private Practice / Firm
# type_of_ownership_Subsidiary or Business Segment
# type_of_ownership_Unknown
# sector_Accounting & Legal
# sector_Aerospace & Defense
# sector_Arts, Entertainment & Recreation
# sector_Biotech & Pharmaceuticals
# sector_Business Services
# sector_Construction, Repair & Maintenance
# sector_Consumer Services
# sector_Education
# sector_Finance
# sector_Government
# sector_Health Care
# sector_Information Technology
# sector_Insurance
# sector_Manufacturing
# sector_Media
# sector_Non-Profit
# sector_Oil, Gas, Energy & Utilities
# sector_Real Estate
# sector_Restaurants, Bars & Food Services
# sector_Retail
# sector_Telecommunications
# sector_Transportation & Logistics
# sector_Unknown
# job_city_Alameda
# job_city_Alhambra
# job_city_Allegheny West
# job_city_Anaheim
# job_city_Arcadia
# job_city_Athens
# job_city_Aurora
# job_city_Austin
# job_city_Berkeley
# job_city_Beverly Hills
# job_city_Brea
# job_city_Brooklyn
# job_city_Broomfield
# job_city_Burbank
# job_city_Burlingame
# job_city_Camden
# job_city_Carson
# job_city_Cedar Park
# job_city_Centennial
# job_city_Cerritos
# job_city_Charlotte
# job_city_Chester Township
# job_city_Chicago
# job_city_City of Industry
# job_city_Columbus
# job_city_Conshohocken
# job_city_Coppell
# job_city_Culver City
# job_city_Cupertino
# job_city_Dallas
# job_city_Daly City
# job_city_Deerfield
# job_city_Denver
# job_city_Downers Grove
# job_city_El Segundo
# job_city_Elk Grove Village
# job_city_Fairfield
# job_city_Far Rockaway
# job_city_Florham Park
# job_city_Fort Eustis
# job_city_Fort Mill
# job_city_Fort Worth
# job_city_Foster City
# job_city_Franklin Lakes
# job_city_Fremont
# job_city_Gainesville
# job_city_Gardena
# job_city_Glendale
# job_city_Glenview
# job_city_Grapevine
# job_city_Great Neck
# job_city_Greenwood Village
# job_city_Hampton
# job_city_Haworth
# job_city_Hoboken
# job_city_Horsham
# job_city_Houston
# job_city_Indianapolis
# job_city_Irving
# job_city_Irwindale
# job_city_Jacksonville
# job_city_Jersey City
# job_city_Kent
# job_city_King of Prussia
# job_city_Kirkland
# job_city_Lackland AFB
# job_city_Lake Success
# job_city_Lakewood
# job_city_Long Beach
# job_city_Long Island City
# job_city_Los Angeles
# job_city_Los Gatos
# job_city_Malvern
# job_city_Manhasset
# job_city_Marina del Rey
# job_city_Marlton
# job_city_Menlo Park
# job_city_Millbrae
# job_city_Mooresville
# job_city_Mount Laurel
# job_city_Mountain View
# job_city_National City
# job_city_New York
# job_city_Newark
# job_city_Newport News
# job_city_Newtown Square
# job_city_Norfolk
# job_city_Northfield
# job_city_Northridge
# job_city_Oakland
# job_city_Palo Alto
# job_city_Paoli
# job_city_Parsippany
# job_city_Pasadena
# job_city_Pearland
# job_city_Philadelphia
# job_city_Phoenix
# job_city_Plano
# job_city_Pleasanton
# job_city_Plymouth Meeting
# job_city_Portsmouth
# job_city_Radnor
# job_city_Redmond
# job_city_Redwood City
# job_city_Reedley
# job_city_Richardson
# job_city_Ridley Park
# job_city_Rolling Meadows
# job_city_Round Rock
# job_city_San Antonio
# job_city_San Diego
# job_city_San Fernando
# job_city_San Francisco
# job_city_San Jose
# job_city_San Mateo
# job_city_Santa Clara
# job_city_Santa Monica
# job_city_Scottsdale
# job_city_Seattle
# job_city_Secaucus
# job_city_South Plainfield
# job_city_South San Francisco
# job_city_Spring
# job_city_Stafford
# job_city_Stanford
# job_city_Sugar Land
# job_city_Summit
# job_city_Sunnyvale
# job_city_Tempe
# job_city_Topeka
# job_city_Valley Stream
# job_city_Walnut Creek
# job_city_Wayne
# job_city_Weehawken
# job_city_West Chester
# job_city_West Orange
# job_city_West Point
# job_city_Westerville
# job_city_Whippany
# job_city_Whittier
# job_city_Wilmington
# job_city_Woodland Hills
# job_city_Yorktown
# job_state_AZ
# job_state_CA
# job_state_CO
# job_state_DE
# job_state_FL
# job_state_GA
# job_state_IL
# job_state_IN
# job_state_KS
# job_state_NC
# job_state_NJ
# job_state_NY
# job_state_OH
# job_state_PA
# job_state_SC
# job_state_TX
# job_state_UT
# job_state_VA
# job_state_WA
# hq_city_Alexandria
# hq_city_Allegan
# hq_city_Allentown
# hq_city_Alpharetta
# hq_city_Amsterdam
# hq_city_Anaheim
# hq_city_Arcadia
# hq_city_Arlington
# hq_city_Ashburn
# hq_city_Atlanta
# hq_city_Audubon
# hq_city_Aurora
# hq_city_Austin
# hq_city_Basking Ridge
# hq_city_Bellevue
# hq_city_Bengaluru
# hq_city_Berkeley
# hq_city_Bethesda
# hq_city_Bezons
# hq_city_Bishnupur
# hq_city_Blue Bell
# hq_city_Boca Raton
# hq_city_Boston
# hq_city_Bradenton
# hq_city_Braga
# hq_city_Brentwood
# hq_city_Bronx
# hq_city_Brooklyn
# hq_city_Buffalo
# hq_city_Burbank
# hq_city_Burlingame
# hq_city_Camden
# hq_city_Campbell
# hq_city_Canoga Park
# hq_city_Canton
# hq_city_Carson
# hq_city_Cedar Park
# hq_city_Chadds Ford
# hq_city_Chantilly
# hq_city_Charleston
# hq_city_Charlotte
# hq_city_Cherry Hill
# hq_city_Chesterfield
# hq_city_Chicago
# hq_city_Cleveland
# hq_city_Clinton
# hq_city_Columbia
# hq_city_Columbus
# hq_city_Concord
# hq_city_Cranford
# hq_city_Cupertino
# hq_city_Dallas
# hq_city_Dayton
# hq_city_Deerfield
# hq_city_Denver
# hq_city_Detroit
# hq_city_Dublin
# hq_city_Duluth
# hq_city_Edison
# hq_city_El Cajon
# hq_city_El Segundo
# hq_city_Elk Grove Village
# hq_city_Encinitas
# hq_city_Erdenheim
# hq_city_Evanston
# hq_city_Fairfax
# hq_city_Fairfield
# hq_city_Falls Church
# hq_city_Far Rockaway
# hq_city_Farmington Hills
# hq_city_Florham Park
# hq_city_Fort Worth
# hq_city_Foster City
# hq_city_Fremont
# hq_city_Frisco
# hq_city_Gainesville
# hq_city_Gibsonia
# hq_city_Glen Allen
# hq_city_Glendale
# hq_city_Glenview
# hq_city_Goleta
# hq_city_Great Neck
# hq_city_Guaynabo
# hq_city_Hagerstown
# hq_city_Hastings
# hq_city_Hauppauge
# hq_city_Hercules
# hq_city_Herndon
# hq_city_Hoboken
# hq_city_Holmdel
# hq_city_Houston
# hq_city_Hyderabad
# hq_city_Irvine
# hq_city_Irving
# hq_city_Iselin
# hq_city_Issaquah
# hq_city_Jacksonville
# hq_city_Jersey City
# hq_city_Keswick
# hq_city_King of Prussia
# hq_city_LISBOA
# hq_city_La Jolla
# hq_city_Lake Jackson
# hq_city_Lake Success
# hq_city_Linthicum
# hq_city_Lombard
# hq_city_London
# hq_city_Long Beach
# hq_city_Los Angeles
# hq_city_Los Gatos
# hq_city_Louisville
# hq_city_Luxembourg
# hq_city_Macquarie Park
# hq_city_Madison
# hq_city_Malvern
# hq_city_Marina del Rey
# hq_city_Mc Lean
# hq_city_Melbourne
# hq_city_Memphis
# hq_city_Menlo Park
# hq_city_Miami
# hq_city_Miami Beach
# hq_city_Middleton
# hq_city_Millersville
# hq_city_Milton
# hq_city_Minneapolis
# hq_city_Monmouth Junction
# hq_city_Monroe
# hq_city_Morristown
# hq_city_Mount Laurel
# hq_city_Mountain View
# hq_city_Mumbai
# hq_city_N New Hyde Park
# hq_city_Natick
# hq_city_National City
# hq_city_New Delhi
# hq_city_New York
# hq_city_Newark
# hq_city_Newport
# hq_city_Newport News
# hq_city_Noida
# hq_city_Norcross
# hq_city_North Brunswick
# hq_city_Northfield
# hq_city_Northridge
# hq_city_Northville
# hq_city_Norwalk
# hq_city_Oakland
# hq_city_Orem
# hq_city_Orlando
# hq_city_Ottawa
# hq_city_Overland Park
# hq_city_Palo Alto
# hq_city_Paris
# hq_city_Park Ridge
# hq_city_Pasadena
# hq_city_Pearland
# hq_city_Phila
# hq_city_Philadelphia
# hq_city_Phoenix
# hq_city_Piscataway
# hq_city_Pittsburgh
# hq_city_Plainsboro
# hq_city_Plano
# hq_city_Pleasanton
# hq_city_Portsmouth
# hq_city_Princeton
# hq_city_Providence
# hq_city_Queens Village
# hq_city_Raleigh
# hq_city_Redwood City
# hq_city_Reno
# hq_city_Renton
# hq_city_Reston
# hq_city_Richardson
# hq_city_Richmond
# hq_city_Rochester
# hq_city_Rockaway
# hq_city_Rockville
# hq_city_Rolling Meadows
# hq_city_Rusk
# hq_city_Saint Louis
# hq_city_San Antonio
# hq_city_San Diego
# hq_city_San Francisco
# hq_city_San Jose
# hq_city_San Mateo
# hq_city_San Rafael
# hq_city_Sandy
# hq_city_Santa Barbara
# hq_city_Santa Clara
# hq_city_Santa Cruz
# hq_city_Santa Monica
# hq_city_Seattle
# hq_city_Secaucus
# hq_city_Shepton Mallet
# hq_city_Singapore
# hq_city_Smithfield
# hq_city_Somerset
# hq_city_South Jordan
# hq_city_South Plainfield
# hq_city_Southfield
# hq_city_Spring
# hq_city_Stafford
# hq_city_Stamford
# hq_city_Stanford
# hq_city_Stans
# hq_city_Stavanger
# hq_city_Sterling
# hq_city_Sunnyvale
# hq_city_Taipei
# hq_city_Tampa
# hq_city_Tarrytown
# hq_city_Tarzana
# hq_city_Tempe
# hq_city_Tigard
# hq_city_Tokyo
# hq_city_Toronto
# hq_city_Troy
# hq_city_Upland
# hq_city_Valley Stream
# hq_city_Vancouver
# hq_city_Walldorf
# hq_city_Walnut Creek
# hq_city_Waltham
# hq_city_Washington
# hq_city_Wayne
# hq_city_Wellesley
# hq_city_West Chester
# hq_city_West Orange
# hq_city_West Point
# hq_city_Westfield
# hq_city_Whittier
# hq_city_Williamsville
# hq_city_Wilmington
# hq_city_Woodridge
# hq_city_Yakima
# hq_city_Zurich
# hq_state_AZ
# hq_state_Australia
# hq_state_CA
# hq_state_CO
# hq_state_CT
# hq_state_Canada
# hq_state_DC
# hq_state_DE
# hq_state_FL
# hq_state_France
# hq_state_GA
# hq_state_Germany
# hq_state_IA
# hq_state_IL
# hq_state_IN
# hq_state_India
# hq_state_Japan
# hq_state_KS
# hq_state_KY
# hq_state_Luxembourg
# hq_state_MA
# hq_state_MD
# hq_state_MI
# hq_state_MN
# hq_state_MO
# hq_state_NC
# hq_state_NH
# hq_state_NJ
# hq_state_NV
# hq_state_NY
# hq_state_Norway
# hq_state_OH
# hq_state_PA
# hq_state_PR
# hq_state_Portugal
# hq_state_RI
# hq_state_SC
# hq_state_Singapore
# hq_state_South Korea
# hq_state_Switzerland
# hq_state_TN
# hq_state_TX
# hq_state_Taiwan
# hq_state_UT
# hq_state_United Kingdom
# hq_state_VA
# hq_state_WA
# hq_state_WI
# hq_state_WV
# size
# revenue
# age
# rating
# SQL
# Excel
# Tableau
# R
# Power BI
# SAS
# Word
# PowerPoint
# AWS
# Python
# Bachelor
# Master
# No_degree

# %%
best_features = ['age','job_title','company_name','type_of_ownership','sector','job_city','job_state','hq_city','hq_state','size','revenue','age','rating',\
                'SQL','Excel','Tableau','R','Power BI','SAS','Word','PowerPoint','AWS','Python','Bachelor','Master','No_degree'
                ]

# %%
len(selected_feature_names)
# Out:
# 2754

# %%
len(selected_feature_indices)
# Out:
# 1377

# %%
len(best_features)
# Out:
# 26

# %%
param_grids = {
    'SVR': {
        'model__C': [0.1, 1, 10],
        'model__epsilon': [0.01, 0.1, 0.5],
        'model__kernel': ['linear', 'poly', 'rbf']
    },
    'Decision Tree': {
        'model__max_depth': [None, 5, 10, 20],
        'model__min_samples_split': [2, 5, 10]
    },
    'Random Forest': {
        'model__n_estimators': [100, 200],
        'model__max_depth': [None, 10, 20],
        'model__min_samples_split': [2, 5]
    },
    'ElasticNet': {
        'model__alpha': [0.1, 0.5, 1.0],
        'model__l1_ratio': [0.1, 0.5, 0.9]
    },
    'KNN': {
        'model__n_neighbors': [3, 5, 7],
        'model__weights': ['uniform', 'distance']
    },
    'Gradient Boosting': {
        'model__n_estimators': [100, 200],
        'model__learning_rate': [0.01, 0.1, 0.2],
        'model__max_depth': [3, 5, 7]
    }
}

models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(max_iter=5000),
    'ElasticNet': ElasticNet(),
    'SVR': SVR(),
    'KNN Regression': KNeighborsRegressor(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor()
}

# %%
best_model = None
best_score = float('-inf')

def evaluate_model_with_grid_search(model, model_name, param_grid=None):
    global best_model, best_score
    pipeline = Pipeline(steps=[
        ('preprocessor', ct),
        ('feature_selection', SelectFromModel(estimator=feature_selection_model, threshold='median')),
        ('model', model)
    ])
    
    if param_grid:
        grid_search = GridSearchCV(pipeline, param_grid=param_grid, cv=5, n_jobs=-1)
        grid_search.fit(X_train, y_train)
        best_estimator = grid_search.best_estimator_
        r_train = best_estimator.score(X_train, y_train)
        r_test = best_estimator.score(X_test, y_test)
        y_train_pred = best_estimator.predict(X_train)
        y_test_pred = best_estimator.predict(X_test)
        mae_train = mean_absolute_error(y_train, y_train_pred)
        mae_test = mean_absolute_error(y_test, y_test_pred)
        print(f'{model_name}:')
        print(f'  Best Params: {grid_search.best_params_}')
        print(f'  Train r-score = {r_train:.4f}')
        print(f'  test r-score = {r_test:.4f}')
        print(f'  Train MAE = {mae_train:.4f}')
        print(f'  Test MAE = {mae_test:.4f}')
        if r_test > best_score:
            best_score = r_test
            best_model = best_estimator
    else:
        pipeline.fit(X_train, y_train)
        r_train = pipeline.score(X_train, y_train)
        r_test = pipeline.score(X_test, y_test)
        y_train_pred = pipeline.predict(X_train)
        y_test_pred = pipeline.predict(X_test)
        mae_train = mean_absolute_error(y_train, y_train_pred)
        mae_test = mean_absolute_error(y_test, y_test_pred)
        print(f'{model_name}:')
        print(f'  Train r-score = {r_train:.4f}')
        print(f'  val r-score = {r_test:.4f}')
        print(f'  Train MAE = {mae_train:.4f}')
        print(f'  Test MAE = {mae_test:.4f}')
        if r_test > best_score:
            best_score = r_test
            best_model = pipeline

# %%
for model_name, model in models.items():
    param_grid = param_grids.get(model_name, None)
    evaluate_model_with_grid_search(model, model_name, param_grid)
# Out:
# Linear Regression:
#   Train r-score = 0.8731
#   val r-score = 0.0729
#   Train MAE = 4.7468
#   Test MAE = 16.4348
# Ridge Regression:
#   Train r-score = 0.7828
#   val r-score = 0.3100
#   Train MAE = 8.3773
#   Test MAE = 14.8864
# Lasso Regression:
#   Train r-score = 0.1853
#   val r-score = 0.1985
#   Train MAE = 16.1906
#   Test MAE = 16.0036
# ElasticNet:
#   Best Params: {'model__alpha': 0.1, 'model__l1_ratio': 0.9}
#   Train r-score = 0.3319
#   test r-score = 0.3294
#   Train MAE = 14.7180
#   Test MAE = 14.7695
# SVR:
#   Best Params: {'model__C': 1, 'model__epsilon': 0.5, 'model__kernel': 'linear'}
#   Train r-score = 0.4024
#   test r-score = 0.3149
#   Train MAE = 12.6273
#   Test MAE = 13.9913
# KNN Regression:
#   Train r-score = 0.3989
#   val r-score = 0.0843
#   Train MAE = 13.8572
#   Test MAE = 17.1532
# Decision Tree:
#   Best Params: {'model__max_depth': 5, 'model__min_samples_split': 10}
#   Train r-score = 0.3814
#   test r-score = 0.3190
#   Train MAE = 14.0801
#   Test MAE = 14.8239
# Random Forest:
#   Best Params: {'model__max_depth': 10, 'model__min_samples_split': 2, 'model__n_estimators': 200}
#   Train r-score = 0.6156
#   test r-score = 0.3883
#   Train MAE = 11.2893
#   Test MAE = 13.9015
# Gradient Boosting:
#   Best Params: {'model__learning_rate': 0.1, 'model__max_depth': 5, 'model__n_estimators': 100}
#   Train r-score = 0.5997
#   test r-score = 0.4019
#   Train MAE = 11.8327
#   Test MAE = 13.8298

# %%
pipeline = Pipeline(steps=[
        ('preprocessor', ct),
        ('feature_selection', SelectFromModel(estimator=feature_selection_model, threshold='median')),
        ('model', XGBRegressor())
    ])

param_grid = {
    'model__learning_rate': [0.1, 0.3],
    'model__max_depth': [3, 5, 7],
    'model__n_estimators': [50, 100, 200]
}

grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=3, scoring='neg_mean_absolute_error', verbose=1)

grid_search.fit(X_train, y_train)

# Print best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", -grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Parameters: {'model__learning_rate': 0.3, 'model__max_depth': 3, 'model__n_estimators': 50}
# Best CV Score: 14.655068895551892

# %%
best_pipeline = grid_search.best_estimator_
best_pipeline.fit(X_train, y_train)
y_pred = best_pipeline.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Test MAE: {mae:.4f}')
print(f'Test R-squared: {r2:.4f}')
# Out:
# Test MAE: 13.9745
# Test R-squared: 0.3965

# %%
if best_model:
    joblib.dump(best_pipeline, 'xgboost_best_pipeline.pkl')
    print('Best model saved to xg_boost.pkl')
# Out:
# Best model saved to xg_boost.pkl
